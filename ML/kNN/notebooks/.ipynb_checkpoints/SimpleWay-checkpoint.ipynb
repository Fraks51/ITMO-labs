# %%
import main
from matplotlib import pyplot as plt
import pandas as pd


def draw_plot(x, y):
    plt.plot(x, y, label = '{}, {}, {}'.format('triweight', 'euclidean', 'variable'))
    plt.ylabel('F - мера')
    plt.xlabel('Ширина окна')
    plt.legend(loc='upper center')
    plt.show()

# %%
    normalized_dataset_values = main.get_normalized_dataset('../data/seeds.csv')
    len_dataset = len(normalized_dataset_values)
    n, m = len_dataset * 9 // 10, len(normalized_dataset_values[0]) - 1
    x = []
    y = []
    for i in range(1, 25):
        x.append(i)
        y.append(main.parameterized_regression('triweight', 'euclidean', 'variable', i, False, n, m,
                                               normalized_dataset_values))
    draw_plot(x, y)
