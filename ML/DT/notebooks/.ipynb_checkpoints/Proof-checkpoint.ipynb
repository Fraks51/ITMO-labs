# %%
from matplotlib import pyplot as plt
import pandas as pd

data_test = pd.read_csv("../data/03_test.csv")
clazz = data_test['y'].values
x = data_test["x1"].values
y = data_test["x27"].values
plt.scatter(x, y, c=clazz, cmap='winter', marker=(4,0))
plt.show()
